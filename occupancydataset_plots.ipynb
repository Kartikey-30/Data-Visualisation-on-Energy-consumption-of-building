# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# %%
#plot of Occupancy dataset of ACB building on sunday

occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/ACB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-02'].plot()
df_s['2017-04-03'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of ACB building on monday

occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/ACB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-08'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of BH building on sunday 
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/BH.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-02'].plot() 
df_s['2017-04-03'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of dining building on monday and sunday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/DB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-04'].plot()
#df_s['2017-04-02'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df_o.describe()
# Out:
#        occupancy_count
# count    178427.000000
# mean         58.475242
# std          53.335947
# min           1.000000
# 25%          17.000000
# 50%          44.000000
# 75%          81.000000
# max         340.000000

# %%
##plot of Occupancy dataset of girls hostel on sunday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/GH.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04'].plot()
df_s['2017-06'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of girls hostel on monday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/GH.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-03'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of library on sunday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/LB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04'].plot()
df_s['2017-06'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of library on monday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/LB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-03'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of lecture hall on monday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/LCB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04'].plot() 
df_s['2017-06'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of lecture hall on sunday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/LCB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-02'].plot()
df_s['2017-04-03'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of SRB(facility building) on monday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/SRB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2017-04-03'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#plot of Occupancy dataset of SRB(facility building) on sunday
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/SRB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
df_s['2015-04-03'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
# relationship analysis 
corelation = SRB.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [88], in <cell line: 2>()
#       1 # relationship analysis
# ----> 2 corelation = SRB.corr()
#
# NameError: name 'SRB' is not defined

# %%
occupancy_data_direc = "K:/new/IIITD_occupancy_dataset/ACB.csv"
df_o = pd.read_csv(occupancy_data_direc,index_col = 'timestamp')
df_o.index = pd.to_datetime(df_o.index,unit = 's')
df_o.index =  df_o.index + datetime.timedelta(minutes = 60*5 + 30) 
df_s = pd.Series(data = df_o.occupancy_count,index = df_o.index)
ax = df_s['2017-04']
ax2 = df_s['2017-06']
ax.plot()
ax2.plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>
